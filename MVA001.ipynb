# %% [markdown]
# <a href="https://colab.research.google.com/github/siriwat-heart/Multivariate/blob/main/MVA001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Scalar, Vector, Matrix

# %% [markdown]
# ### Scalar

# %%
import numpy as np

# %%
scalar_a = 10 #scalar
print(scalar_a)
# Out:
# 10

# %% [markdown]
# ### Vector

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
vector_b = np.zeros([2,1]) ##vector
vector_b[0,0] = 2
vector_b[1,0] = 3
print(vector_b)
print(vector_b.shape)
# Out:
# [[2.]
#  [3.]]
# (2, 1)

# %%
vector_c = np.array([[1],[3]])
print(vector_c)
print(vector_c.shape)
# Out:
# [[1]
#  [3]]
# (2, 1)

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(vector_b[0,0],vector_b[1,0],'or')

# %% [markdown]
# ขนาดของ vector คำนวณได้โดย พิธากอรัส

# %%
vector_b_size = ((vector_b[0,0]**2) + (vector_b[1,0]**2))**0.5
print(vector_b_size)
# Out:
# 3.605551275463989

# %% [markdown]
# ## Matrix

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
matrix_d = np.array([[2,3],[1,4],[-1,1]])
print(matrix_d)
# Out:
# [[ 2  3]
#  [ 1  4]
#  [-1  1]]

# %%
matrix_d = matrix_d.T
print(matrix_d)
# Out:
# [[ 2  1 -1]
#  [ 3  4  1]]

# %%
matrix_d[0,:]
# Out:
# array([ 2,  1, -1])

# %%
plt.plot(matrix_d[0,:],matrix_d[1,:], 'or') ## plot(ค่าX, ค่าy, หน้าตาของจุด)
plt.plot(0,0, '.b') 
plt.plot([0,0],[-1,5],'^:k')
plt.plot([-1.5,2.5],[0,0],'>:k')

# %% [markdown]
# ## Transpose

# %%
A = np.array([[3,-1,2],[1,5,4]])
print(A)
# Out:
# [[ 3 -1  2]
#  [ 1  5  4]]

# %%
A.T
# Out:
# array([[ 3,  1],
#        [-1,  5],
#        [ 2,  4]])

# %% [markdown]
# ### Matrix Multiply

# %% [markdown]
# $B = A*A'$

# %%
B = np.dot(A,A.T)
print(B)
# Out:
# [[14  6]
#  [ 6 42]]

# %% [markdown]
# ## Determinant
# $Det(B)$

# %%
np.linalg.det(B)
# Out:
# 551.9999999999998

# %% [markdown]
# linalg = linear algebra

# %% [markdown]
# matrix algebra เพิ่มเติม

# %%
plt.plot([0,1],[0,1], '-r') ## vector [1,1]
plt.plot(0,0, '.b') 
plt.plot([0,0],[-1,5],'^:k')
plt.plot([-1.5,2.5],[0,0],'>:k')

# %%
B = np.array([[1,2],[3,4]])
B
# Out:
# array([[1, 2],
#        [3, 4]])

# %% [markdown]
# การคูณ Matrix ($B.v$) คือ การทำ linear transformation

# %%
v = np.array([[1],[1]])
v
# Out:
# array([[1],
#        [1]])

# %%
Bv = np.dot(B,v)
Bv
# Out:
# array([[3],
#        [7]])

# %%
plt.plot([0,Bv[0,0]],[0,Bv[1,0]], '-g') ## vector Bv
plt.plot([0,1],[0,1], '-r') ## vector [1,1]
plt.plot(0,0, '.b') 
plt.plot([0,0],[-1,5],'^:k')
plt.plot([-1.5,2.5],[0,0],'>:k')

# %% [markdown]
# Determinant ของ Matrix ( Det(B) ) คือ พื้นที่ของ unit vector ที่ถูกเปลี่ยนไป โดย Matrix นั้นๆ

# %% [markdown]
# # QUIZ 1 fed 21

# %%
plt.plot([0,Bv[0,0]],[0,Bv[1,0]], '-g') ## vector Bv
plt.plot([3,3],[7,0], ':g') ## วาดจุดไข่ปลา พื้นที่ของ Bv
plt.plot([3,0],[7,7], ':g') ## วาดจุดไข่ปลา พื้นที่ของ Bv
plt.plot([0,1],[0,1], '-r') ## vector v ([1,1])
plt.plot([1,1],[1,0], ':r') ## วาดจุดไข่ปลา พื้นที่ของ v
plt.plot([1,0],[1,1], ':r') ## วาดจุดไข่ปลา พื้นที่ของ v
plt.plot(0,0, '.b') 
plt.plot([0,0],[-1,8],'^:k')
plt.plot([-1.5,3.5],[0,0],'>:k')

# %% [markdown]
# Identity matrix ($I$)
#
# $BI = B = IB$

# %%
iden2 = np.identity(2)

# %%
B
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
np.dot(B,iden2)
# Out:
# array([[1., 2.],
#        [3., 4.]])

# %%
np.dot(iden2,B)
# Out:
# array([[1., 2.],
#        [3., 4.]])

# %%
C = np.array([[-1,2],[2,4]])
C
# Out:
# array([[-1,  2],
#        [ 2,  4]])

# %%
np.dot(B,C)
# Out:
# array([[ 3, 10],
#        [ 5, 22]])

# %%
np.dot(C,B)
# Out:
# array([[ 5,  6],
#        [14, 20]])

# %% [markdown]
# การบ้านในห้อง (Quiz 1- commit: quiz 1feb21)
# หา
# ![det 3by3.PNG](data:image/png;base64,...)

# %%
mat_ex1 = np.array([[3,1,6],[7,4,5],[2,-7,1]])
print(mat_ex1)
# Out:
# [[ 3  1  6]
#  [ 7  4  5]
#  [ 2 -7  1]]

# %%
H = np.array([[3,1,6],[7,4,5],[2,-7,1]])
H
# Out:
# array([[ 3,  1,  6],
#        [ 7,  4,  5],
#        [ 2, -7,  1]])

# %%
np.linalg.det(H)
# Out:
# -221.99999999999997

# %% [markdown]
# Eigen value กับ Eigen vector
#
# - Eigen value ($\lambda$) -> $|A-\lambda I| = 0$
# - Eigen vector ($x$) -> $Ax = \lambda x$

# %% [markdown]
# ## HW 5 หา Eigen value กับ Eigen vector ของ
# ![HW5.PNG](data:image/png;base64,...)

# %%
A = np.array([[1,0],[1,3]])
A
# Out:
# array([[1, 0],
#        [1, 3]])

# %% [markdown]
# ### หา Eigen vector

# %%
Eve = np.array([[1,0], [1,3]])
v,e = np.linalg.eig(Eve)
v;e
# Out:
# array([[ 0.        ,  0.89442719],
#        [ 1.        , -0.4472136 ]])

# %% [markdown]
# ### หา Eigen value

# %%
Eva = np.array([[1,0], [1,3]])
np.linalg.eigvals(Eva)
# Out:
# array([3., 1.])

# %% [markdown]
# eigen vectors and eigen values of covarience matrix of data
#
# จากรูป มีจุดข้อมูล 16 จุด และมี attribute 2 มิติ
# เราจะสร้างเป็น data matrix ที่มีรูปร่าง (shape) ? = (2,16)
#
# ![main-qimg-cd58f0ea7a4eb1b5b9800a1ccb418495.png](data:image/png;base64,...)

# %%
X = np.array([[1,2,-3,4],[4,5,-3,2]])
print(f'data X =\n {X}')
C_X = np.cov(X)
print(f'Covarience ของ X คือ \n {C_X}')
# Out:
# data X =
#  [[ 1  2 -3  4]
#  [ 4  5 -3  2]]
# Covarience ของ X คือ
#  [[ 8.66666667  7.66666667]
#  [ 7.66666667 12.66666667]]

# %%
W,V = np.linalg.eig(C_X)

# %%
W
# Out:
# array([ 2.74342378, 18.58990955])

# %%
print(W[1])
print(V[:,1])
# Out:
# 18.589909549336475
# [-0.6113829  -0.79133492]

# %%
plt.plot(X[0,:],X[1,:],'or')
plt.plot([0,3*V[0,1]],[0,3*V[1,1]],'<-b')

# %% [markdown]
# ### Inverse Matrix
# inverse ของ $A$ เขียน $A^{-1}$
# นิยาม $A*A^{-1} = I = A^{-1}*A$

# %%
C_X
# Out:
# array([[ 8.66666667,  7.66666667],
#        [ 7.66666667, 12.66666667]])

# %%
inv_C_X = np.linalg.inv(C_X)
print(inv_C_X)
# Out:
# [[ 0.24836601 -0.1503268 ]
#  [-0.1503268   0.16993464]]

# %% [markdown]
# ตรวจสอบ

# %%
np.dot(C_X,inv_C_X)
# Out:
# array([[1.00000000e+00, 2.23193529e-16],
#        [1.26018779e-16, 1.00000000e+00]])

# %%
np.dot(inv_C_X,C_X)
# Out:
# array([[1.00000000e+00, 1.26018779e-16],
#        [2.23193529e-16, 1.00000000e+00]])

# %%
np.linalg.inv(inv_C_X)
# Out:
# array([[ 8.66666667,  7.66666667],
#        [ 7.66666667, 12.66666667]])

# %% [markdown]
# ## การ load data

# %%
import pandas as pd

# %%
pollution_data = pd.read_csv('/content/pollution.txt',sep='\t+') #\t+ คือใช้ tab แบ่งข้อมูล \s+ คือใช้ space แบ่งข้อมูล 
pollution_data
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
#               City  SO2  Temp   Man   Pop  Wind   Rain  RainDays
# 0          Phoenix   10  70.3   213   582   6.0   7.05        36
# 1      Little Rock   13  61.0    91   132   8.2  48.52       100
# 2    San Francisco   12  56.7   453   716   8.7  20.66        67
# 3           Denver   17  51.9   454   515   9.0  12.95        86
# 4         Hartford   56  49.1   412   158   9.0  43.37       127
# 5       Wilmington   36  54.0    80    80   9.0  40.25       114
# 6       Washington   29  57.3   434   757   9.3  38.89       111
# 7     Jacksonville   14  68.4   136   529   8.8  54.47       116
# ...
